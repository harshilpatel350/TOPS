# %% [markdown]
# # Session 05 — Industry Applications of Generative AI**Focus:** Practical applications using free/local tools — no paid APIs.

# %% [markdown]
# ## Objectives1. Build an IPL match summariser.2. Create a restaurant chatbot.3. Implement a playlist filter.4. Demonstrate prompt engineering techniques.5. Generate `ipl_summary.txt`.6. Discuss industry challenges.

# %% [markdown]
# ## Theory### Generative AI in IndustryGenerative AI is transforming industries beyond image generation:| Sector | Application | Impact ||--------|------------|--------|| Sports | Automated commentary and match summaries | Faster content delivery || Hospitality | AI chatbots for ordering and recommendations | Reduced staffing costs || Entertainment | Personalised playlist curation | Higher user engagement || Marketing | Prompt-engineered content generation | Scalable campaigns |```mermaidgraph TD    A[Generative AI] --> B[Text Generation]    A --> C[Image Generation]    A --> D[Code Generation]    B --> E[Summarisation]    B --> F[Chatbots]    B --> G[Content Creation]    C --> H[Product Design]    D --> I[Developer Tools]```

# %% [markdown]
# ## Learning Outcomes- Build practical NLP applications without paid APIs.- Design rule-based chatbots with intent detection.- Apply extractive summarisation to domain-specific text.- Use pandas for data filtering and analysis.- Understand prompt engineering patterns.

# %% [markdown]
# ---## Setup

# %%
import sysfrom pathlib import PathPROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()if str(PROJECT_ROOT) not in sys.path:    sys.path.insert(0, str(PROJECT_ROOT))import pandas as pdfrom src.utils import setup_loggingfrom src.config import OUTPUTS_DIR, ensure_dirsfrom src.summarizer import summarize_ipl, SAMPLE_IPL_REPORTfrom src.chatbot import RestaurantChatbotfrom src.playlist import (    catalogue_to_dataframe, filter_by_genre, filter_by_mood,    filter_by_artist, filter_by_decade, filter_by_bpm_range,)from src.prompt_engineering import (    get_all_examples, format_example,)setup_logging()ensure_dirs()print('All modules loaded ✓')

# %% [markdown]
# ---## 1. IPL Match Summariser

# %%
# Display the full reportprint('FULL IPL REPORT')print('=' * 70)print(SAMPLE_IPL_REPORT)print(f'\nTotal characters: {len(SAMPLE_IPL_REPORT)}')

# %%
# Generate and save summarysummary = summarize_ipl(num_sentences=5)print('\nGENERATED SUMMARY')print('=' * 70)print(summary)print(f'\nSummary characters: {len(summary)}')print(f'Compression ratio: {len(summary)/len(SAMPLE_IPL_REPORT):.1%}')

# %%
# Verify ipl_summary.txt was createdsummary_path = OUTPUTS_DIR / 'ipl_summary.txt'assert summary_path.exists(), 'ipl_summary.txt not found!'print(f'✓ ipl_summary.txt saved at: {summary_path}')print(f'  Content: {summary_path.read_text(encoding="utf-8")[:200]}...')

# %% [markdown]
# ---## 2. Restaurant Chatbot

# %%
bot = RestaurantChatbot(
    name="GenAI Bistro"
)  # Simulate a conversationconversation = [    'Hello!',    'Show me the menu',    'What do you recommend?',    'I want Margherita Pizza',    'Add Caesar Salad please',    'I would like a Mango Lassi',    'Can I get the bill?',    'Thank you, goodbye!',]for msg in conversation:    print(f'👤 USER: {msg}')    response = bot.respond(msg)    print(f'🤖 BOT:  {response}')    print()

# %%
# Conversation analysisconv_analysis = pd.DataFrame({    'User Message': conversation,    'Detected Intent': [bot.detect_intent(m) for m in conversation],})conv_analysis.index = range(1, len(conv_analysis) + 1)conv_analysis.index.name = 'Turn'conv_analysis

# %% [markdown]
# ---## 3. Playlist Filter

# %%
# Full catalogueplaylist_df = catalogue_to_dataframe()print(f'Total songs: {len(playlist_df)}')playlist_df

# %%
# Filter by genreprint('\n🎵 Pop songs:')pop_songs = filter_by_genre(playlist_df, 'Pop')pop_songs

# %%
# Filter by moodprint('\n😊 Happy songs:')happy_songs = filter_by_mood(playlist_df, 'happy')happy_songs

# %%
# Filter by artistprint('\n🎤 Ed Sheeran songs:')ed_songs = filter_by_artist(playlist_df, 'Ed Sheeran')ed_songs

# %%
# Filter by decadeprint('\n📅 2010s songs:')decade_songs = filter_by_decade(playlist_df, 2010)decade_songs

# %%
# Filter by BPM range (workout songs)print('\n🏃 Workout songs (BPM 100-180):')workout_songs = filter_by_bpm_range(playlist_df, 100, 180)workout_songs

# %% [markdown]
# ---## 4. Prompt Engineering Examples

# %%
examples = get_all_examples()for ex in examples:    print(format_example(ex))    print()

# %%
# Summary tableprompt_summary = pd.DataFrame({    'Technique': [ex.technique for ex in examples],    'Use Case': [        'Simple classification/generation',        'Guided output with examples',        'Multi-step reasoning',        'Audience-targeted responses',        'Structured instruction following',        'Creative constrained generation',    ],    'When to Use': [        'Model has strong zero-shot capability',        'Output format needs to be specific',        'Math, logic, or multi-step problems',        'Different audiences need different depth',        'Fine-tuning or batch processing',        'Creative tasks with boundaries',    ],})prompt_summary.index = range(1, len(prompt_summary) + 1)prompt_summary.index.name = '#'prompt_summary

# %% [markdown]
# ---## 5. Industry Challenges

# %%
challenges = pd.DataFrame({    'Challenge': [        'Hallucination',        'Bias and Fairness',        'Data Privacy',        'Intellectual Property',        'Computational Cost',        'Evaluation Difficulty',        'Regulatory Compliance',        'Adversarial Attacks',    ],    'Description': [        'Models generate plausible but factually incorrect content',        'Training data biases are reflected in outputs',        'Models may memorise and leak sensitive training data',        'Unclear ownership of AI-generated content',        'Large models require expensive GPU infrastructure',        'No single metric captures generation quality comprehensively',        'Varying global regulations (EU AI Act, etc.)',        'Models vulnerable to prompt injection and jailbreaking',    ],    'Mitigation': [        'RAG, fact-checking, human-in-the-loop',        'Diverse training data, bias auditing',        'Differential privacy, data deduplication',        'Clear licensing, watermarking',        'Model distillation, quantisation',        'Multi-metric evaluation (FID, BLEU, human eval)',        'Compliance frameworks, transparency reports',        'Input validation, guardrails, red-teaming',    ],})challenges.index = range(1, len(challenges) + 1)challenges.index.name = '#'challenges

# %% [markdown]
# ---## Summary- **IPL Summariser:** Extractive approach using term-frequency scoring — no LLM needed.- **Restaurant Chatbot:** Rule-based intent detection handles menus, orders, and billing.- **Playlist Filter:** Pandas-powered filtering by genre, mood, artist, decade, and BPM.- **Prompt Engineering:** Six techniques demonstrated with prompts, responses, and explanations.- **Industry Challenges:** Eight key challenges with mitigation strategies.

# %% [markdown]
# ---## Interview Questions1. How does extractive summarisation differ from abstractive?2. What are the limitations of rule-based chatbots vs LLM-powered ones?3. Explain the concept of prompt engineering and why it matters.4. What is RAG and how does it reduce hallucination?5. How would you evaluate a chatbot's effectiveness?6. What ethical considerations arise from generative AI in media?7. Compare zero-shot, few-shot, and chain-of-thought prompting.8. How can differential privacy protect user data in generative models?

# %% [markdown]
# ---## References1. Lewis, P. et al. (2020). *Retrieval-Augmented Generation for Knowledge-Intensive NLP*. NeurIPS.2. Wei, J. et al. (2022). *Chain-of-Thought Prompting Elicits Reasoning in LLMs*. NeurIPS.3. EU Artificial Intelligence Act (2024). *Official Regulation*.4. Bender, E. et al. (2021). *On the Dangers of Stochastic Parrots*. FAccT.
